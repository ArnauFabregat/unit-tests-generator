# %%
import json
from src.raggraph.walker import build_graph_from_directory

# %%
g = build_graph_from_directory(path="../src", save_graph=True)

# %%
print("Nodes:", g.number_of_nodes())
print("Edges:", g.number_of_edges())
# Out:
# Nodes: 54
# Edges: 63

# %%
# Print nodes for inspection
for n, data in list(g.nodes(data=True)):
    print(n, "\n\t", json.dumps(data, indent=2))
    print()
# Out:
# ../src/model.py
# 	 {
#   "type": "file",
#   "name": "model.py",
#   "file": "../src/model.py",
#   "signature": "None",
#   "docstring": "None",
# ...

# %%
# Print edges for inspection
for src, dest, data in list(g.edges(data=True)):
    print(src, "--", data["rel"], "-->", dest)
    print()
# Out:
# ../src/model.py -- defines --> ../src/model.py::class::MonotonicLinear
#
# ../src/model.py -- defines --> ../src/model.py::class::MonotonicNN
#
# ../src/model.py::class::MonotonicLinear -- has_method --> ../src/model.py::method::MonotonicLinear.__init__
#
# ../src/model.py::class::MonotonicLinear -- has_method --> ../src/model.py::method::MonotonicLinear.forward
#
# ../src/model.py::class::MonotonicNN -- has_method --> ../src/model.py::method::MonotonicNN.__init__
#
# ../src/model.py::class::MonotonicNN -- has_method --> ../src/model.py::method::MonotonicNN._init_weights
#
# ../src/model.py::class::MonotonicNN -- has_method --> ../src/model.py::method::MonotonicNN.forward
#
# ../src/model.py::class::MonotonicNN -- has_method --> ../src/model.py::method::MonotonicNN.fit
#
# ../src/model.py::class::MonotonicNN -- has_method --> ../src/model.py::method::MonotonicNN.predict_proba
#
# ...
